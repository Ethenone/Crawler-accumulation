# %%
import pandas as pd
uni = pd.read_csv("出生地信息处理.csv")
uni.head()
print(len(uni))
# Out:
# 2740

# %%
js = pd.read_csv("base地级市.csv")
for i in range(uni.shape[0]):
    js.loc[js["市"]==uni["市"][i],f'{uni["当选年份"][i]}']=js.loc[js["市"]==uni["市"][i],f'{uni["当选年份"][i]}']+1

print(js)
# Out:
#        省    市  1948  1955  1956  1957  1980  1983  1984  1985  ...  2004
# 0    安徽省  安庆市     0     2     0     0     3     0     0     0  ...     0  \
# 1    安徽省  蚌埠市     0     0     0     0     0     0     0     0  ...     0
# 2    安徽省  亳州市     0     0     0     0     0     0     0     0  ...     0
# 3    安徽省  池州市     0     0     0     0     0     0     0     0  ...     0
# 4    安徽省  滁州市     0     0     0     0     2     0     0     0  ...     0
# ..   ...  ...   ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# 284  浙江省  绍兴市     3     5     0     0     4     0     0     0  ...     0
# 285  浙江省  台州市     1     2     0     0     2     0     0     0  ...     0
# 286  浙江省  温州市     1     1     0     0     1     0     0     0  ...     0
# 287  浙江省  舟山市     0     0     0     0     0     0     0     0  ...     0
# 288  重庆市  重庆市     0     3     0     1     2     0     0     0  ...     0
#
#      2005  2007  2009  2011  2013  2015  2017  2019  2021
# ...

# %%
js.to_csv("count3.csv",encoding='utf_8_sig')
