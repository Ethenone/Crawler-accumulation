# %%
# import urllib.request as req
import requests
import json
url = "https://dmfw.mca.gov.cn/9095/stname/listPub"
data = {
    "page":1,
    "size":10,
    "stName":"宜兴",
    "year":0
}
res = requests.post(url=url,data=data)
print(res.text)
# Out:
# {"total":0,"records":[]}

# %%
dicti = json.loads(res.text)['records']
print(dicti[0])
data = dicti[0]['city_name']
print(data)
# Out:
# {'id': '3a12558a92668db687ae3b135fa40385', 'place_code': '14118110522100000007', 'standard_name': '宜兴', 'roman_alphabet_spelling': 'Yíxīng', 'ethnic_minorities_writing': '', 'place_type': '城镇居民点', 'place_type_code': '22100', 'province_name': '山西省', 'city_name': '吕梁市', 'area_name': '孝义市', 'area': '141181105', 'city': None, 'province': None, 'gdm': {'type': 'multipoint', 'coordinates': [[111.7461319, 37.0822292]]}, 'pdm': None}
# 吕梁市

# %%
import pandas as pd
data = pd.read_csv('出生地总表.csv')
print(data['出生地'][0])
# Out:
# 北京
